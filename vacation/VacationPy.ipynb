# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data = pd.read_csv("city_weather_date.csv")
weather_data.dropna()
# Out:
#                city   temp  Cloudiness Country        Date  Humidity    Lat  \
# 0           bubaque  22.59          69      GW  1585037014        55  11.28
# 1          klaksvik   4.00         100      FO  1585037014        86  62.23
# 2         busselton  30.73          51      AU  1585037014        13 -33.65
# 3            dikson -10.41          69      RU  1585037014        89  73.51
# 4              lebu  14.39         100      CL  1585037014        98 -37.62
# ..              ...    ...         ...     ...         ...       ...    ...
# 560  victoria point  21.83          75      AU  1585037040        83 -27.58
# 561            kang  28.59           0      BW  1585037040        36 -23.68
# 562      carutapera  27.99          51      BR  1585037040        75  -1.20
# 563            daru  24.69         100      PG  1585037040        93  -9.08
# 564         jeremie  19.39          41      HT  1585037040        84  18.65
#
#         Lng  Max Temp  Wind Speed
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
locations = weather_data[["Lat", "Lng"]]
humidity = weather_data["Humidity"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# Narrow down the DataFrame to find your ideal weather condition.
#
# For example:
# A max temperature lower than 80 degrees but higher than 70.
# Wind speed less than 10 mph.
# Zero cloudiness.
# Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.
# Note: Feel free to adjust to your specifications but be sure to limit the number of rows returned by your API requests to a reasonable number.
# * Drop any rows will null values.

# %%
hotel_df = weather_data[(weather_data['Max Temp'] < 60) & 
                      (weather_data['Max Temp'] > 20) &
                      (weather_data['Cloudiness'] == 0) & 
                      (weather_data['Wind Speed'] < 10) ]
hotel_df
# Out:
#                   city   temp  Cloudiness Country        Date  Humidity  \
# 11             kirando  25.39           0      TZ  1585037015        69
# 23           karasburg  32.09           0     NaN  1585037015        18
# 33            karratha  30.29           0      AU  1585037016        72
# 51        puerto ayora  22.78           0      EC  1585037016        86
# 58             la joya  22.22           0      MX  1585037017        55
# 63               birao  36.29           0      CF  1585037017         7
# 102              moron  19.97           0      AR  1585037019        88
# 114   puerto escondido  20.79           0      MX  1585037019        78
# 124            tautira  27.90           0      PF  1585037020        69
# 128    arraial do cabo  22.09           0      BR  1585037020        77
# 142          tecoanapa  21.99           0      MX  1585037021        73
# 145                sur  24.19           0      OM  1585037021        46
# ...

# %%
hotel_df.reset_index(drop=True)
# Out:
#                  city   temp  Cloudiness Country        Date  Humidity    Lat  \
# 0             kirando  25.39           0      TZ  1585037015        69  -7.42
# 1           karasburg  32.09           0     NaN  1585037015        18 -28.02
# 2            karratha  30.29           0      AU  1585037016        72 -20.74
# 3        puerto ayora  22.78           0      EC  1585037016        86  -0.74
# 4             la joya  22.22           0      MX  1585037017        55  18.67
# 5               birao  36.29           0      CF  1585037017         7  10.28
# 6               moron  19.97           0      AR  1585037019        88 -34.65
# 7    puerto escondido  20.79           0      MX  1585037019        78  15.85
# 8             tautira  27.90           0      PF  1585037020        69 -17.73
# 9     arraial do cabo  22.09           0      BR  1585037020        77 -22.97
# 10          tecoanapa  21.99           0      MX  1585037021        73  16.52
# ...

# %%
hotel_data = []
hotel_not_exist = []

# %%
target_search = "hotel"
radius = 5000 

params = {
    "radius": radius,
    "keyword": target_search,
    "key": g_key
}

for index, row in hotel_df.iterrows():

    lat = row["Lat"]
    lng = row["Lng"]
    city = row["city"]
    country = row["Country"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)

    # convert to json
    name_address = name_address.json()

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_data.append({"name":name_address["results"][0]["name"], 
                         "city": city,
                         "country": country})

    except:
        hotel_not_exist.append(index)
        print("Missing field/result... skipping.")

# %%
for row in hotel_not_exist:
    hotel_df.drop(row, inplace = True)

# %%
hotel_df.reset_index(drop=True,inplace = True)

# %%
city_hotel_df = pd.DataFrame(hotel_data)
narrowed_city_df = city_hotel_df.rename(columns={"name":"Hotel Name",
                                    "city":"City",
                                    "country":"Country"})
narrowed_city_df
# Out:
#                                            Hotel Name               City  \
# 0                                     Lakeshore Lodge            kirando
# 1                                      Sunset Chalets          karasburg
# 2                                ibis Styles Karratha           karratha
# 3                                           Albatross       puerto ayora
# 4                                       Hotel Cabildo              moron
# 5                             Selina Puerto Escondido   puerto escondido
# 6                                      Hotel da Canoa    arraial do cabo
# 7                                     Hotel Garapacho          tecoanapa
# 8                                     Sur Plaza Hotel                sur
# 9                                  Abaco Beach Resort      marsh harbour
# 10                                        Mansu Hotel             lashio
# 11                       Sinclairs Bayview Port Blair         port blair
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
# **row take key="value" from each row
hotel_info = [info_box_template.format(**row) for index, row in narrowed_city_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, 
                                 dissipating=False, 
                                 max_intensity=100)


marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)


# Add marker layer ontop of heat map
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
